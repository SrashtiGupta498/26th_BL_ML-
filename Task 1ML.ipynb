# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Food.csv')
df
# Out:
#              Name  Price    Place   Color   Cuisine         Taste Calories  \
# 0          Paneer     70   Jaipur   white    Indian  MilkyFlavour  120kcal
# 1           pizza    120   Jaipur   brown   Italian        cheesy  200Kcal
# 2           Pasta     50  Jodhpur   white   Italian         spicy  140kcal
# 3          Dhokla     30   Gujrat  yellow   Gujrati         salty   20kcal
# 4           Kawab    400  Lucknow  yellow   Arabian         spicy  400kcal
# 5    cholebatuure     75   Jaipur   white    Indian         spicy  300kcal
# 6          Burger     50   Indore  yellow   Italian        cheesy  100Kcal
# 7           Momos     20   Indore   white   Chinese         spicy  200kcal
# 8           lassi     20   Jaipur   white   Punjabi        creamy   10Kcal
# 9    rajma chawal    100   Punjab  yellow   Punjabi         spicy   50kcal
# 10  choclate cake    500  Dholpur  yellow  american        creamy  250kcal
# ...

# %%
df.loc[df['Price'].idxmax()]
# Out:
# Name        choclate cake
# Price                 500
# Place             Dholpur
# Color              yellow
# Cuisine          american
# Taste              creamy
# Calories          250kcal
# Protein                no
# Qty                     1
# Rating                4.9
# Name: 10, dtype: object

# %%
df.loc[df['Price'].idxmin()]
# Out:
# Name          Momos
# Price            20
# Place        Indore
# Color         white
# Cuisine     Chinese
# Taste         spicy
# Calories    200kcal
# Protein          no
# Qty         1 plate
# Rating          4.7
# Name: 7, dtype: object

# %%
data=df[(df['Place']=='Jaipur') & (df['Color']=='white')]
data
# Out:
#            Name  Price   Place  Color  Cuisine         Taste Calories Protein  \
# 0        Paneer     70  Jaipur  white   Indian  MilkyFlavour  120kcal     yes
# 5  cholebatuure     75  Jaipur  white   Indian         spicy  300kcal     yes
# 8         lassi     20  Jaipur  white  Punjabi        creamy   10Kcal     yes
#
#        Qty  Rating
# 0      1kg     4.4
# 5  2 plate     4.8
# 8  1 glass     3.9

# %%
data["Name"]
# Out:
# 0          Paneer
# 5    cholebatuure
# 8           lassi
# Name: Name, dtype: object

# %%
for x in df.index:
     if df.loc[x,'Rating']==df["Rating"].max():
        print(df.loc[x,'Cuisine'])
# Out:
# Indian

# %%
df['Taste'].value_counts()
# Out:
# spicy           6
# creamy          2
# salty           2
# cheesy          2
# sweet           1
# MilkyFlavour    1
# lemon           1
# Name: Taste, dtype: int64

# %%
df[(df['Taste']=='sweet') & (df['Place']=='Indore')]
# Out:
#           Name  Price   Place  Color Cuisine  Taste Calories Protein Qty  \
# 14  Gulabjamun    400  Indore  brown  Indian  sweet  120kcal     yes  90
#
#     Rating
# 14    10.0
